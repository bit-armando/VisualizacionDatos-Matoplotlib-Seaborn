# %% [markdown]
# Seaborn ofrece ofrece diferentes graficos para graficar datos categoricos

# %%
import seaborn as sns

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Grafica de cantidad

# %%
sns.countplot(data=tips, x='day',hue='sex');

# %% [markdown]
# ## Grafica de caja

# %%
sns.boxplot(data=tips, x='day', y='total_bill', hue='sex');

# %% [markdown]
# ## Diagrama de puntos

# %%
sns.swarmplot(data=tips, x='day', y='total_bill', hue='sex', dodge=True);

# %% [markdown]
# Los graficos se pueden combinar con otros

# %%
sns.boxplot(data= tips, x= 'day', y = 'total_bill', hue= 'sex', dodge=True);
sns.swarmplot(data= tips, x= 'day', y = 'total_bill', hue= 'sex', dodge=True, color = '0', marker= '<');
# Out:
# /home/armando/anaconda3/envs/scrap/lib/python3.10/site-packages/seaborn/categorical.py:166: FutureWarning: Setting a gradient palette using color= is deprecated and will be removed in version 0.13. Set `palette='dark:0'` for same effect.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Violin:** Parecido al boxplot muestra la densidad de los datos en comparacion `split()`pero este no muestra los cuartiles

# %%
sns.violinplot(data= tips, x= 'day', y = 'total_bill', hue= 'sex', split=True);

# %% [markdown]
# `catplot()`, con kind podemos cambiar el tipo de gráfico y se puede agregar otra variable col

# %%
sns.catplot(data= tips, x= 'day', y = 'total_bill', hue= 'sex', dodge=True, kind= 'box', col= 'time');
